# %% [markdown]
# # Oasis Infobyte Internship Task 01

# %% [markdown]
# ### Iris Flower clasification

# %% [markdown]
# #### Code by : Avinash Pariha

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
# First Insert Data set 
iris = pd.read_csv("iris.csv")

# %%
iris.keys()
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Print some Data
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Generate Discriptive Statistics
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
sn.swarmplot(x='Species',y='SepalLengthCm',data=iris)
plt.show()

# %%
sn.swarmplot(x='Species',y='SepalWidthCm',data=iris)
plt.show()

# %%
sn.swarmplot(x='Species',y='PetalLengthCm',data=iris)
plt.show()
# Out:
# C:\ProgramData\ana\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sn.swarmplot(x='Species',y='SepalLengthCm',data=iris)
plt.show()

# %%
# Split the data into train and test set
train,test = train_test_split(iris,test_size = 0.25)

# %%
# Train the data
train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 25    26            5.0           3.0            1.6           0.2
# 139  140            6.9           3.1            5.4           2.1
# 12    13            4.8           3.0            1.4           0.1
# 50    51            7.0           3.2            4.7           1.4
# 118  119            7.7           2.6            6.9           2.3
# ..   ...            ...           ...            ...           ...
# 3      4            4.6           3.1            1.5           0.2
# 9     10            4.9           3.1            1.5           0.1
# 96    97            5.7           2.9            4.2           1.3
# 66    67            5.6           3.0            4.5           1.5
# 41    42            4.5           2.3            1.3           0.3
#
#              Species
# 25       Iris-setosa
# 139   Iris-virginica
# 12       Iris-setosa
# 50   Iris-versicolor
# 118   Iris-virginica
# ..               ...
# ...

# %%
# Test the data
test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 68    69            6.2           2.2            4.5           1.5
# 124  125            6.7           3.3            5.7           2.1
# 98    99            5.1           2.5            3.0           1.1
# 95    96            5.7           3.0            4.2           1.2
# 36    37            5.5           3.5            1.3           0.2
# 134  135            6.1           2.6            5.6           1.4
# 127  128            6.1           3.0            4.9           1.8
# 121  122            5.6           2.8            4.9           2.0
# 88    89            5.6           3.0            4.1           1.3
# 38    39            4.4           3.0            1.3           0.2
# 16    17            5.4           3.9            1.3           0.4
# 120  121            6.9           3.2            5.7           2.3
# 33    34            5.5           4.2            1.4           0.2
# ...

# %%
# Spllit the features and targets
train_x = train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
train_y = train.Species

# %%
# Features of train data
train_x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 25             5.0           3.0            1.6           0.2
# 139            6.9           3.1            5.4           2.1
# 12             4.8           3.0            1.4           0.1
# 50             7.0           3.2            4.7           1.4
# 118            7.7           2.6            6.9           2.3
# ..             ...           ...            ...           ...
# 3              4.6           3.1            1.5           0.2
# 9              4.9           3.1            1.5           0.1
# 96             5.7           2.9            4.2           1.3
# 66             5.6           3.0            4.5           1.5
# 41             4.5           2.3            1.3           0.3
#
# [112 rows x 4 columns]

# %%
# Target of train data
train_y
# Out:
# 25         Iris-setosa
# 139     Iris-virginica
# 12         Iris-setosa
# 50     Iris-versicolor
# 118     Iris-virginica
#             ...
# 3          Iris-setosa
# 9          Iris-setosa
# 96     Iris-versicolor
# 66     Iris-versicolor
# 41         Iris-setosa
# Name: Species, Length: 112, dtype: object

# %%
test_x = test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
test_y = test.Species

# %%
# Train the model
model = DecisionTreeClassifier()
model.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
# Predict the accuracy
pred = model.predict(test_x)
metrics.accuracy_score(pred,test_y)
# Out:
# 0.9736842105263158

# %%
# Test the model
test = np.array([[4,5,6,4]])
species_name = model.predict(test)
print(species_name)
# Out:
# ['Iris-virginica']
# C:\ProgramData\ana\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
