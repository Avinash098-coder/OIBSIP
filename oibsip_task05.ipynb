# %% [markdown]
# # Oasis Infobyte Internship Task 05

# %% [markdown]
# ## sales prediction

# %% [markdown]
# ### Code by : Avinash Parihar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
Advertising = pd.read_csv('Advertising.csv')

# %%
print(Advertising.keys())
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
Advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
Advertising
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
Advertising.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
Advertising.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
plt.figure(figsize =(10,8))
sns.swarmplot(x ='TV',y = 'Sales',data = Advertising )
plt.show()
# Out:
# C:\ProgramData\ana\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize =(10,8))
sns.swarmplot(x = 'Radio',y = 'Sales',data = Advertising )
plt.show()
# Out:
# C:\ProgramData\ana\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize =(10,8))
sns.swarmplot(x = 'Newspaper',y = 'Sales',data = Advertising )
plt.show()
# Out:
# C:\ProgramData\ana\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\ana\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
train,test = train_test_split(Advertising,test_size = 0.25)

# %%
train
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 70           71  199.1   30.6       38.7   18.3
# 86           87   76.3   27.5       16.0   12.0
# 145         146  140.3    1.9        9.0   10.3
# 63           64  102.7   29.6        8.4   14.0
# 2             3   17.2   45.9       69.3    9.3
# ..          ...    ...    ...        ...    ...
# 53           54  182.6   46.2       58.7   21.2
# 11           12  214.7   24.0        4.0   17.4
# 25           26  262.9    3.5       19.5   12.0
# 180         181  156.6    2.6        8.3   10.5
# 6             7   57.5   32.8       23.5   11.8
#
# [150 rows x 5 columns]

# %%
test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 149         150   44.7   25.8       20.6   10.1
# 125         126   87.2   11.8       25.9   10.6
# 171         172  164.5   20.9       47.4   14.5
# 20           21  218.4   27.7       53.4   18.0
# 67           68  139.3   14.5       10.2   13.4
# 152         153  197.6   23.3       14.2   16.6
# 168         169  215.4   23.6       57.6   17.1
# 161         162   85.7   35.8       49.3   13.3
# 71           72  109.8   14.3       31.7   12.4
# 52           53  216.4   41.7       39.6   22.6
# 165         166  234.5    3.4       84.8   11.9
# 188         189  286.0   13.9        3.7   15.9
# 141         142  193.7   35.4       75.6   19.2
# 91           92   28.6    1.5       33.0    7.3
# 129         130   59.6   12.0       43.1    9.7
# 28           29  248.8   27.1       22.9   18.9
# 41           42  177.0   33.4       38.7   17.1
# 179         180  165.6   10.0       17.6   12.6
# 88           89   88.3   25.5       73.4   12.9
# ...

# %%
train_x = train[[ 'TV', 'Radio', 'Newspaper']]
train_y= train.Sales

# %%
train_x
# Out:
#         TV  Radio  Newspaper
# 70   199.1   30.6       38.7
# 86    76.3   27.5       16.0
# 145  140.3    1.9        9.0
# 63   102.7   29.6        8.4
# 2     17.2   45.9       69.3
# ..     ...    ...        ...
# 53   182.6   46.2       58.7
# 11   214.7   24.0        4.0
# 25   262.9    3.5       19.5
# 180  156.6    2.6        8.3
# 6     57.5   32.8       23.5
#
# [150 rows x 3 columns]

# %%
train_y
# Out:
# 70     18.3
# 86     12.0
# 145    10.3
# 63     14.0
# 2       9.3
#        ...
# 53     21.2
# 11     17.4
# 25     12.0
# 180    10.5
# 6      11.8
# Name: Sales, Length: 150, dtype: float64

# %%
test_x = test[[ 'TV', 'Radio', 'Newspaper']]

# %%
test_y = test.Sales

# %%
model=LinearRegression()
model.fit(train_x,train_y)
pred = model.predict(test_x)

# %%
pred
# Out:
# array([ 9.66081534,  9.01623658, 14.3600023 , 18.17326464, 11.97513129,
#        16.37254424, 17.25851849, 13.46806425, 10.54837951, 20.72157021,
#        14.34218417, 18.75394374, 18.46165437,  4.32014336,  7.75483143,
#        19.49282223, 17.30575859, 12.36076955, 11.64409212,  3.49878458,
#        10.17797147, 12.03948438, 23.01690364,  6.62405236,  9.97691431,
#        21.78748785, 14.38303201,  8.28115336, 11.93033326, 19.76782327,
#        23.45159543, 16.34307239,  9.59983452, 16.12647314,  6.40914635,
#        18.22621841, 16.44333199, 21.21478467, 13.94895133, 20.35540615,
#        12.31754885, 15.2218474 ,  9.350635  , 12.30411536, 23.37629576,
#        17.59465742, 16.32058484, 21.35646426, 18.94655474,  6.8938897 ])

# %%
metrics.r2_score(pred,test_y)
# Out:
# 0.9036110841212743

# %%
plt.figure(figsize=(10,8))
sns.regplot(x=test_y,y=pred,scatter_kws={'color':'red'})
# Out:
# <AxesSubplot:xlabel='Sales'>
